# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %% [markdown]
# **Exercise 1 (Tidying a collaboration)**

# %% [markdown]
# Task 1
#
# We like to convert the filename to a more useful numerical format. Specifically, we want to convert month-date-city.txt. (i.e. may-10-singapore.txt) to a mm-dd-city.txt (i.e. 05-10-singapore.txt) format.
#
# Using the following dictionary (or otherwise), write a snippet of Python code to convert 'oct-08_singapore.txt' to 10-08-singapore.txt

# %%
filepath = 'os-collaboration-exercise-data'

# %%
import os


months = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

filename = 'oct-07_singapore.txt'
os.rename(os.path.join(filepath, filename), os.path.join(filepath, f"{months['oct']}{filename[3:]}"))

# %% [markdown]
# Task 2
#
# Incorporate your previous code into a function named rename_my_file(old_file_name) that accepts the old filename as the argument and returns the new file name.

# %%
def rename_my_file(old_file_name):
    fn = old_file_name
    return f"{months[fn[:3]]}{fn[3:]}"

# %% [markdown]
# Task 3

# %%
for i in [
    'oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
    'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
    'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
    'jan-01_tokyo.txt'
]:
    try:
        new_name = rename_my_file(i)
        os.rename(os.path.join(filepath, i), os.path.join(filepath, new_name))
        print(f'{i} ----> {new_name}')
    except:
        print(f'{i}: file not found.')
# Out:
# oct-08_singapore.txt: file not found.
# jul-10_cairo.txt ----> 07-10_cairo.txt
# may-15_dhaka.txt ----> 05-15_dhaka.txt
# may-13_cairo.txt: file not found.
# oct-21_cairo.txt: file not found.
# jan-10_singapore.txt: file not found.
# jun-20_tokyo.txt ----> 06-20_tokyo.txt
# aug-06_jakarta.txt: file not found.
# dec-21_karachi.txt: file not found.
# jan-01_tokyo.txt: file not found.

# %% [markdown]
# Task 4

# %%
import glob


filelist = glob.glob(os.path.join(filepath, '*.txt'))
for i in filelist:
    try:
        file_name = i.split(os.path.sep)[-1]
        new_name = rename_my_file(file_name)
        os.rename(i, os.path.join(filepath, new_name))
        print(f'{i} ----> {new_name}')
    except Exception as err:
        print(f'{i}: Error - {err}')
# Out:
# os-collaboration-exercise-data\01-01_manila.txt: Error - '01-'
# os-collaboration-exercise-data\01-01_osaka.txt: Error - '01-'
# os-collaboration-exercise-data\01-02_cairo.txt: Error - '01-'
# os-collaboration-exercise-data\01-02_karachi.txt: Error - '01-'
# os-collaboration-exercise-data\01-02_manila.txt: Error - '01-'
# os-collaboration-exercise-data\01-03_cairo.txt: Error - '01-'
# os-collaboration-exercise-data\01-03_jakarta.txt: Error - '01-'
# os-collaboration-exercise-data\01-03_karachi.txt: Error - '01-'
# os-collaboration-exercise-data\01-03_shanghai.txt: Error - '01-'
# os-collaboration-exercise-data\01-04_cairo.txt: Error - '01-'
# os-collaboration-exercise-data\01-04_jakarta.txt: Error - '01-'
# os-collaboration-exercise-data\01-04_karachi.txt: Error - '01-'
# os-collaboration-exercise-data\01-04_manila.txt: Error - '01-'
# os-collaboration-exercise-data\01-05_cairo.txt: Error - '01-'
# os-collaboration-exercise-data\01-05_melbourne.txt: Error - '01-'
# ...

# %% [markdown]
# Task 5

# %%
city = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for i in city:
    folderpath = os.path.join(filepath, i)
    if not os.path.exists(folderpath):
        os.mkdir(folderpath)

# %% [markdown]
# Task 6

# %%
import shutil


cairolist = glob.glob(os.path.join(filepath, '*cairo.txt'))
for i in cairolist:
    try:
        shutil.copy(i, os.path.join(filepath, 'Cairo'))
    except:
        print('Error. Skipping...')

# %% [markdown]
# Task 7

# %%
for cityname in city:
    citylist = glob.glob(os.path.join(filepath, f'*{cityname.lower()}.txt'))
    # print(citylist)
    for cityfile in citylist:
        try:
            filename = cityfile.split(os.path.sep)[-1]
            shutil.move(cityfile, os.path.join(filepath, cityname, filename))
            print(f'Moving {cityfile} to {cityname}.')
        except:
            print('Error. Skipping...')
